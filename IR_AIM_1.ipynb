# %% [markdown]
# <a href="https://colab.research.google.com/github/Mukeshrs/Citi---IBM-Hackathon---Anonymous/blob/master/IR_AIM_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
pip install google-search-results
# Out:
# ...
#   Created wheel for google-search-results: filename=google_search_results-2.0.0-cp36-none-any.whl size=14922 sha256=d70d944959676ee1268c6dc20846e445e2262381cf3617c71b6e2c0dc96283c5
#   Stored in directory: /root/.cache/pip/wheels/f9/1e/f5/d6d940cda9c759673a0a0a7f0e948a64de15c29c6e8dc07175
# Successfully built google-search-results
# ...

# %%
from serpapi import GoogleSearch

params = {
    "engine": "google",
    "q": "Trump",
    "google_domain": "google.com",
    "tbm": "nws",
    "num": "35"
}

client = GoogleSearch(params)
google = client.get_dict()

print(google)

googledf = google['news_results']

print("News results")

for result in google['news_results']:
    i=0
    print(f"""
Index: {result['position']}
Title: {result['title']}
Snippet: {result['snippet']}
Date: {result['date']}
URL: {result['link']}
""")
# Out:
# {'search_metadata': {'id': '5feb108ce9b12fdb8048d7e3', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/fbb693a645953370/5feb108ce9b12fdb8048d7e3.json', 'created_at': '2020-12-29 11:18:36 UTC', 'processed_at': '2020-12-29 11:18:36 UTC', 'google_url': 'https://www.google.com/search?q=Trump&oq=Trump&num=35&tbm=nws&sourceid=chrome&ie=UTF-8', 'raw_html_file': 'https://serpapi.com/searches/fbb693a645953370/5feb108ce9b12fdb8048d7e3.html', 'total_time_taken': 2.4}, 'search_parameters': {'engine': 'google', 'q': 'Trump', 'google_domain': 'google.com', 'num': '35', 'device': 'desktop', 'tbm': 'nws'}, 'search_information': {'news_results_state': 'Results for exact spelling', 'total_results': 640000000, 'time_taken_displayed': 0.72, 'query_displayed': 'Trump'}, 'people_also_search_for': [{'name': 'House votes to override veto', 'news_results': [{'position': 1, 'link': 'https://www.theguardian.com/us-news/2020/dec/29/house-republicans-join-with-democrats-to-override-trumps-vet
# ...

# %%
from serpapi import GoogleSearch

params = {
    "engine": "bing_news",
    "q": "Trump",
    #"google_domain": "google.com",
    "count": "35",
    "qft": 'interval="9"'
}

client = GoogleSearch(params)
bing = client.get_dict()

print(bing)

bingdf=bing['organic_results']

print("News results")

for result in bing['organic_results']:
    print(f"""
Title: {result['title']}
Snippet: {result['snippet']}
Date: {result['date']}
URL: {result['link']}
""")
# Out:
# {'search_metadata': {'id': '5feb0ffa9ca9f91bba70095b', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/1eeb4f8b53e357ce/5feb0ffa9ca9f91bba70095b.json', 'created_at': '2020-12-29 11:16:10 UTC', 'processed_at': '2020-12-29 11:16:10 UTC', 'bing_news_url': 'https://www.bing.com/news/search?q=Trump&count=35&qft=interval="9"', 'raw_html_file': 'https://serpapi.com/searches/1eeb4f8b53e357ce/5feb0ffa9ca9f91bba70095b.html', 'total_time_taken': 5.09}, 'search_parameters': {'engine': 'bing_news', 'q': 'Trump', 'device': 'desktop', 'count': '35', 'qft': 'interval="9"'}, 'organic_results': [{'title': 'Just how much of a rebuke to Trump is Congress’s veto override?', 'link': 'https://www.washingtonpost.com/politics/2020/12/29/just-how-much-rebuke-trump-is-congresss-veto-override/', 'snippet': 'Republicans in Congress are about to hand President Trump the biggest legislative loss of his presidency by helping Democrats ...', 'source': 'Washington Post', 'date': '11m', 'thumbnail'
# ...

# %%
import pandas as pd


google_df = pd.DataFrame.from_dict(googledf) 
bing_df = pd.DataFrame.from_dict(bingdf)  

new.dtypes
# Out:
#                                                 title  ...                                          thumbnail
# 0   Just how much of a rebuke to Trump is Congress...  ...  ......
# 1   Trump faces looming decision on extending visa...  ...  ......
# 2   Rep. Adam Kinzinger has battled Trump and his ...  ...  ......
# 3   U.S. House overrides Trump's veto of key defen...  ...  ......
# 4   Trump's unplanned gift to Biden: Clean energy ...  ...  ......
# 5   The Newest Trump-Boosted Viral MAGA Star Has T...  ...  ......
# 6   'That Terrifies Me': Trump Rule Allows Natural...  ...  https://www.bing.com/th?id=OVFT.76NACvpgqRRzq5...
# 7   Trump and Republicans prefer Covid tax cuts to...  ...  https://www.bing.com/th?id=OVFT.jwg5-Hx-QbX8GX...
# 8   Don Lemon Says Donald Trump and His Allies Are...  ...  https://www.bing.com/th?id=OVFT.n1FUWSWPw-WTrK...
# 9   Trump opens up federal dollars for private sch...  ...  https://www.bing.com/th?id=OVFT.gPAoY8xJMi-xzd...
# ...
